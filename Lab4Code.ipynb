# %% [markdown]
# <a href="https://colab.research.google.com/github/karayim3/Lab4/blob/main/Lab4Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-30ca3d92-06eb-452d-af6e-71ddf6036635" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30ca3d92-06eb-452d-af6e-71ddf6036635">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ten_cm, twenty_cm, thirty_cm = np.loadtxt("lab4_rubber_tube.csv", skiprows=1, unpack=True, delimiter=',')
print('Rubber tube...')
mass = 0.03 #kg
g = 9.81 #m/s^2
all_change_in_e = [] # we can use append() to store each change_in_e value so that we can later calculate the mean and standard deviation

height = 0.1 #m
for i in range(1, 20):  # range(1, 20) goes from index 1 to 19
  initial_v = ten_cm[i-1]
  final_v = ten_cm[i]
  change_in_e = (0.5*mass*final_v**2 - 0.5*mass*initial_v**2) + (mass * g * height)
  all_change_in_e.append(change_in_e)
  print(f"The change in total energy from Run {i-1} to Run {i} with height {height:.1f}m is {change_in_e:.4f} Joules.")
  # to find the errors, we need error of mass, velocity, distance
  # error of mass = +-0.1g = +-0.0001kg because the scale oscillated between 30.0g and 29.9g
  # error in velocity = +-0.0001m/s because we displayed 3 decimal points
  # error in distance/height = +-0.01cm = +-0.0001m
  # error in e (delta_e/e) = sqrt[(delta_m/m)^2 + 2(delta_v/v)^2 - (delta_m/m)^2 + 2(delta_y/y)^2]
  uncertainty_change_in_e = np.sqrt((0.0001/0.03)**2 + 2 * (0.0001/final_v)**2 + (0.0001/0.03)**2 + 2 * (.0001/height)**2)
  # we use final_v instead of initial_v for the value of v because that is the velocity at that instant
  print(f"The uncertainty in change in total energy from Run {i-1} to Run {i} with height {height}m is +-{uncertainty_change_in_e:.8f} Joules")
print()
height = 0.2 #m
for i in range(1, 20):  # range(1, 20) goes from index 1 to 19
  initial_v = twenty_cm[i-1]
  final_v = twenty_cm[i]
  change_in_e = (0.5*mass*final_v**2 - 0.5*mass*initial_v**2) + (mass * g * height)
  all_change_in_e.append(change_in_e)
  print(f"The change in total energy from Run {i-1} to Run {i} with height {height:.1f}m is {change_in_e:.4f} Joules.")
  # to find the errors, we need error of mass, velocity, distance
  # error of mass = +-0.1g = +-0.0001kg because the scale oscillated between 30.0g and 29.9g
  # error in velocity = +-0.0001m/s because we displayed 3 decimal points
  # error in distance/height = +-0.01cm = +-0.0001m
  # error in e (delta_e/e) = sqrt[(delta_m/m)^2 + 2(delta_v/v)^2 - (delta_m/m)^2 + 2(delta_y/y)^2]
  uncertainty_change_in_e = np.sqrt((0.0001/0.03)**2 + 2 * (0.0001/final_v)**2 + (0.0001/0.03)**2 + 2 * (.0001/height)**2)
  # we use final_v instead of initial_v for the value of v because that is the velocity at that instant
  print(f"The uncertainty in change in total energy from Run {i-1} to Run {i} with height {height}m is +-{uncertainty_change_in_e:.8f} Joules")
print()
height = 0.3 #m
for i in range(1, 20):  # range(1, 20) goes from index 1 to 19
  initial_v = thirty_cm[i-1]
  final_v = thirty_cm[i]
  change_in_e = (0.5*mass*final_v**2 - 0.5*mass*initial_v**2) + (mass * g * height)
  all_change_in_e.append(change_in_e)
  print(f"The change in total energy from Run {i-1} to Run {i} with height {height:.1f}m is {change_in_e:.4f} Joules.")
  # to find the errors, we need error of mass, velocity, distance
  # error of mass = +-0.1g = +-0.0001kg because the scale oscillated between 30.0g and 29.9g
  # error in velocity = +-0.0001m/s because we displayed 3 decimal points
  # error in distance/height = +-0.01cm = +-0.0001m
  # error in e (delta_e/e) = sqrt[(delta_m/m)^2 + 2(delta_v/v)^2 - (delta_m/m)^2 + 2(delta_y/y)^2]
  uncertainty_change_in_e = np.sqrt((0.0001/0.03)**2 + 2 * (0.0001/final_v)**2 + (0.0001/0.03)**2 + 2 * (.0001/height)**2)
  # we use final_v instead of initial_v for the value of v because that is the velocity at that instant
  print(f"The uncertainty in change in total energy from Run {i-1} to Run {i} with height {height}m is +-{uncertainty_change_in_e:.8f} Joules")

print()
# there are 57 pieces of data in all_change_in_e so N = 57. we can find mean with sum()
N = 57
total_avg_change_in_e = sum(all_change_in_e) / N
print("The average value of all changes in E is", format(total_avg_change_in_e, '.4f'), "Joules \n")

# standard deviation = sqrt(sum((x_i - mean)^2)/N-1). so we can take each element of all_change_in_e and subtract the mean from it
# we can access each set of measurements with indexing. [0, 18] is 0.1m, [19, 37] is 0.2m, [38, 56] is 0.3m
e_10cm_sum = 0
e_20cm_sum = 0
e_30cm_sum = 0
sd1_sum = 0 # this will be used in replace of the summation symbol/sigma
sd2_sum = 0
sd3_sum = 0
sd_sum = 0
set_length = 19 # each set has the same amount of measurements

for a in range(19):
  e_10cm_sum += all_change_in_e[a]
avg1_change_in_e = e_10cm_sum / set_length
print(f"The average of the first set is {avg1_change_in_e:.4f} Joules")
for b in range(19):
  sd1_part1 = (all_change_in_e[b] - avg1_change_in_e)**2
  sd1_sum += sd1_part1
standard_dev1 = np.sqrt(sd1_sum/(set_length))
print("The standard deviation of the first measured set of events is", format(standard_dev1, '.4f'), "Joules \n")

for c in range(19, 38):
  e_20cm_sum += all_change_in_e[c]
avg2_change_in_e = e_20cm_sum / set_length
print(f"The average of the second set is {avg2_change_in_e:.4f} Joules")
for d in range(19, 38):
  sd2_part1 = (all_change_in_e[d] - avg2_change_in_e)**2
  sd2_sum += sd2_part1
standard_dev2 = np.sqrt(sd2_sum/(set_length))
print("The standard deviation of the second measured set of events is", format(standard_dev2, '.4f'), "Joules \n")

for e in range(38, 57):
  e_30cm_sum += all_change_in_e[e]
avg3_change_in_e = e_30cm_sum / set_length
print(f"The average of the third set is {avg3_change_in_e:.4f} Joules")
for f in range(38, 57):
  sd3_part1 = (all_change_in_e[f] - avg3_change_in_e)**2
  sd3_sum += sd3_part1
standard_dev3 = np.sqrt(sd3_sum/(set_length))
print("The standard deviation of the third measured set of events is", format(standard_dev3, '.4f'), "Joules \n")

for g in all_change_in_e:
  sd_part1 = (g - total_avg_change_in_e)**2
  sd_sum += sd_part1
standard_dev = np.sqrt(sd_sum/(N-1))
print("The standard deviation of distribution is", format(standard_dev, '.4f'), "Joules \n")

print("The standard deviation measures how far away from the mean a point is. Because of this, the average value of the change of E has a standard deviation of 0. \n")

# fractional uncertainty = 1/(sqrt(2(N-1)))
fu_part1 = 2*(N-1)
fu_part2 = np.sqrt(fu_part1)
frac_uncertainty = 1/fu_part2
print(f"The fractional uncertainty is {frac_uncertainty:.4f} Joules")
# Out:
# Rubber tube...
# The change in total energy from Run 0 to Run 1 with height 0.1m is 0.0543 Joules.
# The uncertainty in change in total energy from Run 0 to Run 1 with height 0.1m is +-0.00492211 Joules
# The change in total energy from Run 1 to Run 2 with height 0.1m is 0.0031 Joules.
# The uncertainty in change in total energy from Run 1 to Run 2 with height 0.1m is +-0.00492248 Joules
# The change in total energy from Run 2 to Run 3 with height 0.1m is 0.0185 Joules.
# The uncertainty in change in total energy from Run 2 to Run 3 with height 0.1m is +-0.00492288 Joules
# The change in total energy from Run 3 to Run 4 with height 0.1m is 0.0422 Joules.
# The uncertainty in change in total energy from Run 3 to Run 4 with height 0.1m is +-0.00492244 Joules
# The change in total energy from Run 4 to Run 5 with height 0.1m is 0.0142 Joules.
# The uncertainty in change in total energy from Run 4 to Run 5 with height 0.1m is +-0.00492302 Joules
# ...

# %%
import numpy as np
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-3bf9753a-2016-4980-bdb2-7722cb27141e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3bf9753a-2016-4980-bdb2-7722cb27141e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ten_cm, thirty_cm, fifty_cm = np.loadtxt("lab4_paper_tube.csv", skiprows=1, unpack=True, delimiter=',')
# we can use a similar code for the paper tube
print('Paper tube...')
mass = 0.005 #kg
g = 9.81 #m/s^2
all_change_in_e = [] # we can use append() to store each change_in_e value so that we can later calculate the mean and standard deviation
# range function does not allow floats, but np.arange does. we can use this to account for each height (0.1, 0.3, 0.5m)

height = 0.1 #m
for i in range(1, 5):  # range(1, 5) goes from index 1 to 4
  initial_v = ten_cm[i-1]
  final_v = ten_cm[i]
  change_in_e = (0.5*mass*final_v**2 - 0.5*mass*initial_v**2) + (mass * g * height)
  all_change_in_e.append(change_in_e)
  print(f"The change in total energy from Run {i-1} to Run {i} with height {height:.1f}m is {change_in_e:.4f} Joules.")
  # to find the errors, we need error of mass, velocity, distance
  # error of mass = +-0.1g = +-0.0001kg because the scale oscillated between 30.0g and 29.9g
  # error in velocity = +-0.0001m/s because we displayed 3 decimal points
  # error in distance/height = +-0.01cm = +-0.0001m
  # error in e (delta_e/e) = sqrt[(delta_m/m)^2 + 2(delta_v/v)^2 - (delta_m/m)^2 + 2(delta_y/y)^2]
  uncertainty_change_in_e = np.sqrt((0.0001/0.03)**2 + 2 * (0.0001/final_v)**2 + (0.0001/0.03)**2 + 2 * (.0001/height)**2)
  # we use final_v instead of initial_v for the value of v because that is the velocity at that instant
  print(f"The uncertainty in change in total energy from Run {i-1} to Run {i} with height {height}m is +-{uncertainty_change_in_e:.8f} Joules")
print()
height = 0.3 #m
for i in range(1, 5):
  initial_v = thirty_cm[i-1]
  final_v = thirty_cm[i]
  change_in_e = (0.5*mass*final_v**2 - 0.5*mass*initial_v**2) + (mass * g * height)
  all_change_in_e.append(change_in_e)
  print(f"The change in total energy from Run {i-1} to Run {i} with height {height:.1f}m is {change_in_e:.4f} Joules.")
  # to find the errors, we need error of mass, velocity, distance
  # error of mass = +-0.1g = +-0.0001kg because the scale oscillated between 30.0g and 29.9g
  # error in velocity = +-0.0001m/s because we displayed 3 decimal points
  # error in distance/height = +-0.01cm = +-0.0001m
  # error in e (delta_e/e) = sqrt[(delta_m/m)^2 + 2(delta_v/v)^2 - (delta_m/m)^2 + 2(delta_y/y)^2]
  uncertainty_change_in_e = np.sqrt((0.0001/0.03)**2 + 2 * (0.0001/final_v)**2 + (0.0001/0.03)**2 + 2 * (.0001/height)**2)
  # we use final_v instead of initial_v for the value of v because that is the velocity at that instant
  print(f"The uncertainty in change in total energy from Run {i-1} to Run {i} with height {height}m is +-{uncertainty_change_in_e:.8f} Joules")
print()
height = 0.5 #m
for i in range(1, 5):
  initial_v = fifty_cm[i-1]
  final_v = fifty_cm[i]
  change_in_e = (0.5*mass*final_v**2 - 0.5*mass*initial_v**2) + (mass * g * height)
  all_change_in_e.append(change_in_e)
  print(f"The change in total energy from Run {i-1} to Run {i} with height {height:.1f}m is {change_in_e:.4f} Joules.")
  # to find the errors, we need error of mass, velocity, distance
  # error of mass = +-0.1g = +-0.0001kg because the scale oscillated between 30.0g and 29.9g
  # error in velocity = +-0.0001m/s because we displayed 3 decimal points
  # error in distance/height = +-0.01cm = +-0.0001m
  # error in e (delta_e/e) = sqrt[(delta_m/m)^2 + 2(delta_v/v)^2 - (delta_m/m)^2 + 2(delta_y/y)^2]
  uncertainty_change_in_e = np.sqrt((0.0001/0.03)**2 + 2 * (0.0001/final_v)**2 + (0.0001/0.03)**2 + 2 * (.0001/height)**2)
  # we use final_v instead of initial_v for the value of v because that is the velocity at that instant
  print(f"The uncertainty in change in total energy from Run {i-1} to Run {i} with height {height}m is +-{uncertainty_change_in_e:.8f} Joules")

print()
# there are 15 pieces of data in all_change_in_e so N = 57. we can find mean with sum()
N = 15
total_avg_change_in_e = sum(all_change_in_e) / N
print("The average value for all changes in E is", format(total_avg_change_in_e, '.4f'), "Joules \n")

# standard deviation = sqrt(sum((x_i - mean)^2)/N-1). so we can take each element of all_change_in_e and subtract the mean from it
# we can access each set of measurements with indexing. [0, 4] is 0.1m, [5, 9] is 0.2m, [10, 14] is 0.3m
e_10cm_sum = 0
e_30cm_sum = 0
e_50cm_sum = 0
sd1_sum = 0 # this will be used in replace of the summation symbol/sigma
sd3_sum = 0
sd5_sum = 0
sd_sum = 0
set_length = 15 # each set has the same amount of measurements

for a in range(4):
  e_10cm_sum += all_change_in_e[a]
avg1_change_in_e = e_10cm_sum / set_length
print(f"The average of the first set is {avg1_change_in_e:.4f} Joules")
for b in range(4):
  sd1_part1 = (all_change_in_e[b] - avg1_change_in_e)**2
  sd1_sum += sd1_part1
standard_dev1 = np.sqrt(sd1_sum/(set_length))
print("The standard deviation of the first measured set of events is", format(standard_dev1, '.4f'), "Joules \n")

for c in range(4, 8):
  e_30cm_sum += all_change_in_e[c]
avg3_change_in_e = e_30cm_sum / set_length
print(f"The average of the second set is {avg3_change_in_e:.4f} Joules")
for d in range(4, 8):
  sd3_part1 = (all_change_in_e[d] - avg3_change_in_e)**2
  sd3_sum += sd3_part1
standard_dev3 = np.sqrt(sd3_sum/(set_length))
print("The standard deviation of the second measured set of events is", format(standard_dev3, '.4f'), "Joules \n")

for e in range(8, 12):
  e_50cm_sum += all_change_in_e[e]
avg5_change_in_e = e_50cm_sum / set_length
print(f"The average of the third set is {avg5_change_in_e:.4f} Joules")
for f in range(8, 12):
  sd5_part1 = (all_change_in_e[f] - avg5_change_in_e)**2
  sd5_sum += sd5_part1
standard_dev5 = np.sqrt(sd5_sum/(set_length))
print("The standard deviation of the third measured set of events is", format(standard_dev5, '.4f'), "Joules \n")

for g in all_change_in_e:
  sd_part1 = (g - total_avg_change_in_e)**2
  sd_sum += sd_part1
standard_dev = np.sqrt(sd_sum/(N-1))
print("The standard deviation of distribution is", format(standard_dev, '.4f'), "Joules \n")

print("The standard deviation measures how far away from the mean a point is. Because of this, the average value of the change of E has a standard deviation of 0. \n")

# fractional uncertainty = 1/(sqrt(2(N-1)))
fu_part1 = 2*(N-1)
fu_part2 = np.sqrt(fu_part1)
frac_uncertainty = 1/fu_part2
print(f"The fractional uncertainty is {frac_uncertainty:.4f} Joules")
# Out:
# Paper tube...
# The change in total energy from Run 0 to Run 1 with height 0.1m is -0.0010 Joules.
# The uncertainty in change in total energy from Run 0 to Run 1 with height 0.1m is +-0.00492269 Joules
# The change in total energy from Run 1 to Run 2 with height 0.1m is 0.0045 Joules.
# The uncertainty in change in total energy from Run 1 to Run 2 with height 0.1m is +-0.00492279 Joules
# The change in total energy from Run 2 to Run 3 with height 0.1m is 0.0055 Joules.
# The uncertainty in change in total energy from Run 2 to Run 3 with height 0.1m is +-0.00492264 Joules
# The change in total energy from Run 3 to Run 4 with height 0.1m is 0.0036 Joules.
# The uncertainty in change in total energy from Run 3 to Run 4 with height 0.1m is +-0.00492303 Joules
#
# The change in total energy from Run 0 to Run 1 with height 0.3m is 0.0127 Joules.
# The uncertainty in change in total energy from Run 0 to Run 1 with height 0.3m is +-0.00473810 Joules
# ...
